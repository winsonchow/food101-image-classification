# %% [markdown]
# # Food-101 Image Classification

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# ## 2 Project Setup

# %% [markdown]
# ### 2.1 Package setup

# %%
try:
    import torch
    import torchvision
    print(f"torch version: {torch.__version__}")
    print(f"torchvision version: {torchvision.__version__}")
except:
    # !pip install torch torchvision
    import torch
    import torchvision
    print(f"torch version: {torch.__version__}")
    print(f"torchvision version: {torchvision.__version__}")
# Out:
# torch version: 2.0.1
# torchvision version: 0.15.2

# %%
from torch import nn
from torchvision import transforms
from torchinfo import summary

# %%
# Set up device agnostic code
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

print(f"Your device is using {device} to train the models")
# Out:
# Your device is using mps to train the models

# %% [markdown]
# Setting a random seed is a crucial practice for ensuring reproducibility and consistent results. It provides a solid foundation for analysis, experimentation, and model development by reducing the impact of randomness on your results.

# %%
# Set seeds
def set_seeds(seed: int=0):
    # Set seed for CUDA torch operations
    torch.cuda.manual_seed(seed)
    
    # Set seed for MPS torch operations
    torch.mps.manual_seed(seed)
    
    # Set seed for general torch operations
    torch.manual_seed(seed)

# %% [markdown]
# ### 2.1 Download Food-101 Dataset

# %%
from pathlib import Path
import os

dataset_directory = Path("food-101-dataset/images")
image_path = dataset_directory / "images"

# Check if the specified directory exists
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
# Out:
# Did not find food-101-dataset/images/images directory, creating one...

# %%
import os
def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.
  Args:
    dir_path (str or pathlib.Path): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(image_path)

# %%
import torchvision.datasets as datasets


dataset_directory = Path("food-101-dataset/images")

# Get training data
train_data = datasets.Food101(root=dataset_directory,
                              split="train",
                              # transform=transforms.ToTensor(),
                              download=False)

# Get testing data
test_data = datasets.Food101(root=dataset_directory,
                             split="test",
                             # transform=transforms.ToTensor(),
                             download=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 7
#       4 dataset_directory = Path("food-101-dataset/images")
#       6 # Get training data
# ----> 7 train_data = datasets.Food101(root=dataset_directory,
#       8                               split="train",
#       9                               # transform=transforms.ToTensor(),
#      10                               download=False)
#      12 # Get testing data
#      13 test_data = datasets.Food101(root=dataset_directory,
#      14                              split="test",
#      15                              # transform=transforms.ToTensor(),
#      16                              download=False)
#
# File ~/anaconda3/lib/python3.10/site-packages/torchvision/datasets/food101.py:53, in Food101.__init__(self, root, split, transform, target_transform, download)
#      50     self._download()
# ...

# %%
train_data

# %% [markdown]
# ### 2.2 Data Exploration

# %% [markdown]
# ## 3 Data Preprocessing

# %% [markdown]
# ### 3.1 Load Food-101 Dataset

# %% [markdown]
# ### 3.2 Data Preprocessing

# %% [markdown]
# ### 3.3 Data Augmentation

# %% [markdown]
# ## 4 Building the Image Classification Model

# %% [markdown]
# ### 4.1 Choosing a Model Architecture

# %% [markdown]
# ### 4.2 Model Initialisation

# %% [markdown]
# ### 4.3 Training Setup

# %% [markdown]
# ## 5 Training the Model

# %% [markdown]
# ### 5.1 Data Loaders

# %% [markdown]
# ### 5.2 Training Loop

# %% [markdown]
# ## 6 Model Evaluation

# %% [markdown]
# ### 6.1 Validation and Test

# %% [markdown]
# ### 6.2 Visualise Reults

# %% [markdown]
# ## 7 Setting Up a Series of Modelling Experiements

# %% [markdown]
# ### 7.1 Modeling Fine-Tuning and Optimization

# %% [markdown]
# ### 7.2 Transfer Learning

# %% [markdown]
# ### 7.3 View experiments in TensorBoard

# %% [markdown]
# ## 8 Loading the Best Model and Making Predictions

# %% [markdown]
# ## 8 Conclusion
